# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 1.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('P53350')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
# 1               []  Homo sapiens
#
#                                        pref_name  score  species_group_flag  \
# 0           Serine/threonine-protein kinase PLK1   16.0               False
# 1  Cereblon/Serine/threonine-protein kinase PLK1   15.0               False
#
#   target_chembl_id                                  target_components  \
# 0       CHEMBL3024  [{'accession': 'P53350', 'component_descriptio...
# 1    CHEMBL4742280  [{'accession': 'P53350', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN    9606
# 1  PROTEIN-PROTEIN INTERACTION    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *SARS coronavirus 3C-like proteinase* (fifth entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL3024'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       750655                  []
# 1        None             None      1662506                  []
# 2        None             None      1662531                  []
#
#   assay_chembl_id                 assay_description assay_type  \
# 0    CHEMBL763908         Inhibition of PLK1 kinase          B
# 1    CHEMBL864552  Inhibitory activity against Plk1          B
# 2    CHEMBL864552  Inhibitory activity against Plk1          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
#
#   target_organism                      target_pref_name target_tax_id  \
# 0    Homo sapiens  Serine/threonine-protein kinase PLK1          9606
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1687  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1688                                               None             None
# 1689                                               None             None
# 1690                                               None             None
# 1691                                               None             None
#
#       activity_id                                activity_properties  \
# ...

# %%
standard_value_col = 'standard_value'  # Column containing bioactivity values
standard_units_col = 'standard_units'  # Column containing

# %%
def convert_to_nm(row):
  """Converts uM to nM if necessary."""
  # Check if 'standard_value' is not None before converting
  if row[standard_value_col] is not None:
    if row[standard_units_col] == 'uM':
      return float(row[standard_value_col]) * 1000  # uM to nM conversion
    else:
      return float(row[standard_value_col])  # If already nM, return as is
  else:
    return None # or some other default value if you prefer

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# ... (Your existing code to load and process the data) ...

def convert_to_nm(row):
  """Converts uM to nM if necessary."""
  # Check if 'standard_value' is not None before converting
  if row[standard_value_col] is not None:
    if row[standard_units_col] == 'uM':
      return float(row[standard_value_col]) * 1000  # uM to nM conversion
    else:
      return float(row[standard_value_col])  # If already nM, return as is
  else:
    return None # or some other default value if you prefer

# Apply the function and create a new column 'standard_value_nM'
df['standard_value_nM'] = df.apply(convert_to_nm, axis=1)

# Create a new column 'converted' to indicate if the value was converted
df['converted'] = df.apply(lambda row: row[standard_units_col] == 'uM' and row[standard_value_col] is not None, axis=1)

# Display rows where the conversion happened
print("Rows where conversion happened (uM to nM):")
display(df[df['converted']])

# Optionally, display rows where conversion did not happen
print("\nRows where conversion did not happen:")
display(df[~df['converted']])
# Out:
# Rows where conversion happened (uM to nM):
# Empty DataFrame
# Columns: [action_type, activity_comment, activity_id, activity_properties, assay_chembl_id, assay_description, assay_type, assay_variant_accession, assay_variant_mutation, bao_endpoint, bao_format, bao_label, canonical_smiles, data_validity_comment, data_validity_description, document_chembl_id, document_journal, document_year, ligand_efficiency, molecule_chembl_id, molecule_pref_name, parent_molecule_chembl_id, pchembl_value, potential_duplicate, qudt_units, record_id, relation, src_id, standard_flag, standard_relation, standard_text_value, standard_type, standard_units, standard_upper_value, standard_value, target_chembl_id, target_organism, target_pref_name, target_tax_id, text_value, toid, type, units, uo_units, upper_value, value, standard_value_nM, converted]
# Index: []
#
# [0 rows x 48 columns]
# Rows where conversion did not happen:
#                                             action_type activity_comment  \
# ...

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df.standard_value_nM:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  #else:
  #  bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL115220             O=C(Cc1ccc2ccccc2c1)Nc1cc(C2CC2)n[nH]1
# 1          CHEMBL200586                          COC(=O)c1cc2c(C)n[nH]c2s1
# 2          CHEMBL199996          Cc1n[nH]c2sc(C(N)=O)c(NC(=O)Nc3ccccc3)c12
# 3          CHEMBL199658       Cc1n[nH]c2sc(C(N)=O)c(NC(=O)c3ccc(Cl)cc3)c12
# 4          CHEMBL199657       Cc1n[nH]c2sc(C(N)=O)c(NC(=O)c3cccc(Cl)c3)c12
# ...                 ...                                                ...
# 1687      CHEMBL1391547  O=C(O)c1ccc2c(c1)[C@@H]1C=CC[C@@H]1[C@H](c1ccc...
# 1688      CHEMBL3974629  CCOc1cc(N2CCC(O)CC2)ccc1Nc1ncc2c(n1)N(C1CCCC1)...
# 1689      CHEMBL1236095  CCc1cccc(CC)c1NC(=O)c1nn(C)c2c1CCc1cnc(Nc3ccc(...
# 1690      CHEMBL2165191  Cc1cc([C@@H](C)Nc2ccccc2C(=O)O)c2nc(N3CCOCC3)c...
# 1691      CHEMBL1852688  CCN1CCN(c2ccc(Nc3cc(N(C)C(=O)Nc4c(Cl)c(OC)cc(O...
#
#      standard_value
# 0           10000.0
# 1          100000.0
# ...

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#      molecule_chembl_id                              canonical_smiles  \
# 0          CHEMBL115220        O=C(Cc1ccc2ccccc2c1)Nc1cc(C2CC2)n[nH]1
# 1          CHEMBL200586                     COC(=O)c1cc2c(C)n[nH]c2s1
# 2          CHEMBL199996     Cc1n[nH]c2sc(C(N)=O)c(NC(=O)Nc3ccccc3)c12
# 3          CHEMBL199658  Cc1n[nH]c2sc(C(N)=O)c(NC(=O)c3ccc(Cl)cc3)c12
# 4          CHEMBL199657  Cc1n[nH]c2sc(C(N)=O)c(NC(=O)c3cccc(Cl)c3)c12
# ...                 ...                                           ...
# 1087                NaN                                           NaN
# 1088                NaN                                           NaN
# 1089                NaN                                           NaN
# 1092                NaN                                           NaN
# 1093                NaN                                           NaN
#
#      standard_value bioactivity_class
# 0           10000.0          inactive
# 1          100000.0          inactive
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df4.to_csv('bioactivity_data_preprocessed.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-8e9311f0242c> in <cell line: 0>()
# ----> 1 df4.to_csv('bioactivity_data_preprocessed.csv', index=False)
#
# NameError: name 'df4' is not defined

# %%
! ls -l
# Out:
# total 88
# -rw-r--r-- 1 root root 10567 May 15 07:50 bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root 70010 May 15 07:39 bioactivity_data_raw.csv
# drwxr-xr-x 1 root root  4096 May  4 16:26 sample_data

# %% [markdown]
# ---
